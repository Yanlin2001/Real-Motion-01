# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/motion01/net_g_latest.pth
# /kaggle/input/test0227/undersample_abd.pth
# /kaggle/input/test0227/un_motion_abd.pth
# /kaggle/input/test0227/motion_abd.pth
# /kaggle/input/test0227/noise_abd.pth
# /kaggle/input/test0227/un_mo_noise_abd.pth
# /kaggle/input/test001/noise.pth
# /kaggle/input/test001/motion.pth
# /kaggle/input/test0226/un_motion.pth
# /kaggle/input/test0226/un_motion_lr.pth
# /kaggle/input/test0226/undersample.pth
# /kaggle/input/test0226/un__mo_noise.pth
# /kaggle/input/test0227-brain/un_mo_noise.pth
# /kaggle/input/test0224/undersample.pth
# /kaggle/input/test0224/mo_un_no_de.pth
# /kaggle/input/test0224/noise.pth
# /kaggle/input/test0224/mo_un.pth
# /kaggle/input/test0224/degeneration.pth
# /kaggle/input/test0224/mo_un_no.pth
# /kaggle/input/test0224/motion.pth
# /kaggle/input/test0228/un_motion15000.pth
# /kaggle/input/test0228/un_mo_noise15000.pth
# /kaggle/input/test0228/un_mo_noise30000.pth
# /kaggle/input/test0228/undersample30000.pth
# ...

# %%
cd /kaggle/working/
# Out:
# [WinError 3] 系统找不到指定的路径。: '/kaggle/working/'
# o:\MICCAI2024\Real-Motion-01
# e:\anaconda3\envs\test_SR\lib\site-packages\IPython\core\magics\osm.py:393: UserWarning: using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})

# %%
# !git clone https://github.com/Yanlin2001/Real-Motion-01.git
# Out:
# Cloning into 'Real-Motion-01'...
# remote: Enumerating objects: 30335, done.
# remote: Counting objects: 100% (11546/11546), done.
# remote: Compressing objects: 100% (11095/11095), done.
# remote: Total 30335 (delta 518), reused 11458 (delta 431), pack-reused 18789
# Receiving objects: 100% (30335/30335), 1.37 GiB | 41.78 MiB/s, done.
# Resolving deltas: 100% (1354/1354), done.
# Updating files: 100% (24760/24760), done.

# %%
cd O:/MICCAI2024/Real-Motion-01
# Out:
# O:\MICCAI2024\Real-Motion-01

# %%
# !git pull origin master
# Out:
# From https://github.com/Yanlin2001/Real-Motion-01
#  * branch              master     -> FETCH_HEAD
# Already up to date.

# %%
# Install basicsr - https://github.com/xinntao/BasicSR
# We use BasicSR for both training and inference
# !pip install basicsr
# Out:
# ...
# DEPRECATION: Loading egg at e:\anaconda3\lib\site-packages\absl_py-2.0.0-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at e:\anaconda3\lib\site-packages\addict-2.4.0-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at e:\anaconda3\lib\site-packages\cachetools-5.3.2-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at e:\anaconda3\lib\site-packages\fonttools-4.49.0-py3.11-win-amd64.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ...
# DEPRECATION: Loading egg at e:\anaconda3\lib\site-packages\absl_py-2.0.0-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at e:\anaconda3\lib\site-packages\addict-2.4.0-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at e:\anaconda3\lib\site-packages\cachetools-5.3.2-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at e:\anaconda3\lib\site-packages\fonttools-4.49.0-py3.11-win-amd64.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# ...

# %%
# !python setup.py develop
# Out:
# running develop
# running egg_info
# writing realesrgan.egg-info\PKG-INFO
# writing dependency_links to realesrgan.egg-info\dependency_links.txt
# writing requirements to realesrgan.egg-info\requires.txt
# writing top-level names to realesrgan.egg-info\top_level.txt
# reading manifest file 'realesrgan.egg-info\SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# adding license file 'LICENSE'
# writing manifest file 'realesrgan.egg-info\SOURCES.txt'
# running build_ext
# Creating e:\anaconda3\envs\test_sr\lib\site-packages\realesrgan.egg-link (link to .)
# realesrgan 0.3.0 is already the active version in easy-install.pth
#
# Installed o:\miccai2024\real-motion-01
# Processing dependencies for realesrgan==0.3.0
# Searching for tqdm==4.66.2
# Best match: tqdm 4.66.2
# Adding tqdm 4.66.2 to easy-install.pth file
# Installing tqdm-script.py script to e:\anaconda3\envs\test_SR\Scripts
# Installing tqdm.exe script to e:\anaconda3\envs\test_SR\Scripts
#
# ...

# %% [markdown]
# 准备meta文件

# %%
#!python scripts/generate_meta_info.py --input datasets/motion01/train --root datasets/motion01 --meta_info datasets/motion01/meta_info/meta_info_test.txt

# %% [markdown]
# 下载预训练模型

# %%
#!wget https://github.com/xinntao/Real-ESRGAN/releases/download/v0.1.0/RealESRGAN_x4plus.pth -P experiments/pretrained_models

# %% [markdown]
# **Debug测试** *提交时不需要*

# %%
#!python realesrgan/train.py -opt options/train_realesrnet_motion01_under01.yml --debug

# %% [markdown]
# **正式训练**

# %%
#!python realesrgan/test.py -opt options/test_realesrnet_motion01.yml --auto_resume

# %%
#!python realesrgan/test.py -opt options/test_realesrnet_motion02.yml --auto_resume

# %%
#!python realesrgan/test.py -opt options/test_realesrnet_motion03.yml --auto_resume

# %%
#!python realesrgan/test.py -opt options/test_realesrnet_motion04.yml --auto_resume

# %%
#!python realesrgan/test.py -opt options/test_realesrnet_motion05.yml --auto_resume

# %%
#!python realesrgan/test.py -opt options/test_realesrnet_motion06.yml --auto_resume

# %%
#!python realesrgan/test.py -opt options/test_realesrnet_motion07.yml --auto_resume

# %%
#!python realesrgan/test.py -opt options/C0226_realesrnet_motion02_undersample.yml --auto_resume

# %%
#!python realesrgan/test.py -opt options/C0226_realesrnet_motion02_un_motion.yml --auto_resume

# %%
#!python realesrgan/test.py -opt options/C0226_realesrnet_motion02_un_mo_noise.yml --auto_resume

# %%
#!python realesrgan/test.py -opt options/C0226_realesrnet_motion02_un_motion_lr.yml --auto_resume

# %%
#!python realesrgan/test.py -opt options/C0227_realesrnet_motion02_un_mo_noise_brain.yml --auto_resume

# %%
#!python realesrgan/test.py -opt options/C0226_realesrnet_motion02_noise_A1.yml --auto_resume

# %%
#!python realesrgan/test.py -opt options/C0226_realesrnet_motion02_motion_A1.yml --auto_resume

# %%
#!python realesrgan/test.py -opt options/C0226_realesrnet_motion02_noise_A2.yml --auto_resume

# %%
# !python realesrgan/test.py -opt options/C0228_realesrnet_motion02_un_mo_noise_15000.yml --auto_resume
# Out:
# Traceback (most recent call last):
#   File "O:\MICCAI2024\Real-Motion-01\realesrgan\test.py", line 5, in <module>
#     import realesrgan.archs
#   File "o:\miccai2024\real-motion-01\realesrgan\__init__.py", line 2, in <module>
#     from .archs import *
#   File "o:\miccai2024\real-motion-01\realesrgan\archs\__init__.py", line 2, in <module>
#     from basicsr.utils import scandir
#   File "e:\anaconda3\envs\test_SR\lib\site-packages\basicsr\__init__.py", line 4, in <module>
#     from .data import *
#   File "e:\anaconda3\envs\test_SR\lib\site-packages\basicsr\data\__init__.py", line 22, in <module>
#     _dataset_modules = [importlib.import_module(f'basicsr.data.{file_name}') for file_name in dataset_filenames]
#   File "e:\anaconda3\envs\test_SR\lib\site-packages\basicsr\data\__init__.py", line 22, in <listcomp>
#     _dataset_modules = [importlib.import_module(f'basicsr.data.{file_name}') for file_name in dataset_filenames]
# ...

# %%
# !python realesrgan/test.py -opt options/C0228_realesrnet_motion02_un_mo_noise_30000.yml --auto_resume

# %%
# !python realesrgan/test.py -opt options/C0228_realesrnet_motion02_un_motion_15000.yml --auto_resume

# %%
# !python realesrgan/test.py -opt options/C0228_realesrnet_motion02_un_motion_30000.yml --auto_resume

# %%
# !python realesrgan/test.py -opt options/C0228_realesrnet_motion02_undersample_15000.yml --auto_resume

# %%
# !python realesrgan/test.py -opt options/Z0321_realesrnet_motion03_under_h2.yml --auto_resume
# Out:
# ^C

# %%
# !python realesrgan/test.py -opt options/Z0321_realesrnet_motion03_under_v2.yml --auto_resume
# Out:
# Disable distributed.
# 2024-03-21 14:21:24,201 INFO:
#                 ____                _       _____  ____
#                / __ ) ____ _ _____ (_)_____/ ___/ / __ \
#               / __  |/ __ `// ___// // ___/\__ \ / /_/ /
#              / /_/ // /_/ /(__  )/ // /__ ___/ // _, _/
#             /_____/ \__,_//____//_/ \___//____//_/ |_|
#      ______                   __   __                 __      __
#     / ____/____   ____   ____/ /  / /   __  __ _____ / /__   / /
#    / / __ / __ \ / __ \ / __  /  / /   / / / // ___// //_/  / /
#   / /_/ // /_/ // /_/ // /_/ /  / /___/ /_/ // /__ / /<    /_/
#   \____/ \____/ \____/ \____/  /_____/\____/ \___//_/|_|  (_)
#
# Version Information:
# 	BasicSR: 1.4.2
# 	PyTorch: 2.2.1+cu118
# 	TorchVision: 0.17.1+cpu
# 2024-03-21 14:21:24,201 INFO:
#   name: Z0321_realesrnet_motion03_under_v2
#   model_type: RealESRNetModel
#   scale: 1
#   num_gpu: 1
#   manual_seed: 0
#   datasets:[
#     test_1:[
#       name: gt320_h
# ...

# %%
# !python realesrgan/test.py -opt options/C0228_realesrnet_motion02_undersample_test.yml --auto_resume
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(
# Disable distributed.
# Path already exists. Rename it to /kaggle/working/Real-Motion-01/results/C0228_realesrnet_motion02_undersample_test_archived_20240228_174440
# 2024-02-28 17:44:40,255 INFO:
#                 ____                _       _____  ____
#                / __ ) ____ _ _____ (_)_____/ ___/ / __ \
#               / __  |/ __ `// ___// // ___/\__ \ / /_/ /
#              / /_/ // /_/ /(__  )/ // /__ ___/ // _, _/
#             /_____/ \__,_//____//_/ \___//____//_/ |_|
#      ______                   __   __                 __      __
#     / ____/____   ____   ____/ /  / /   __  __ _____ / /__   / /
# ...

# %%
# !python realesrgan/test.py -opt options/C0301_realesrnet_motion02.yml --auto_resume
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(
# Disable distributed.
# 2024-03-01 13:39:24,121 INFO:
#                 ____                _       _____  ____
#                / __ ) ____ _ _____ (_)_____/ ___/ / __ \
#               / __  |/ __ `// ___// // ___/\__ \ / /_/ /
#              / /_/ // /_/ /(__  )/ // /__ ___/ // _, _/
#             /_____/ \__,_//____//_/ \___//____//_/ |_|
#      ______                   __   __                 __      __
#     / ____/____   ____   ____/ /  / /   __  __ _____ / /__   / /
#    / / __ / __ \ / __ \ / __  /  / /   / / / // ___// //_/  / /
#   / /_/ // /_/ // /_/ // /_/ /  / /___/ /_/ // /__ / /<    /_/
# ...

# %%
# !python realesrgan/test.py -opt options/C0303_realesrnet_motion02_undersample_fft.yml --auto_resume
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(
# Disable distributed.
# 2024-03-03 14:54:56,886 INFO:
#                 ____                _       _____  ____
#                / __ ) ____ _ _____ (_)_____/ ___/ / __ \
#               / __  |/ __ `// ___// // ___/\__ \ / /_/ /
#              / /_/ // /_/ /(__  )/ // /__ ___/ // _, _/
#             /_____/ \__,_//____//_/ \___//____//_/ |_|
#      ______                   __   __                 __      __
#     / ____/____   ____   ____/ /  / /   __  __ _____ / /__   / /
#    / / __ / __ \ / __ \ / __  /  / /   / / / // ___// //_/  / /
#   / /_/ // /_/ // /_/ // /_/ /  / /___/ /_/ // /__ / /<    /_/
# ...

# %%
# !python realesrgan/test.py -opt options/C0303_realesrnet_motion02_undersample_pixel_fft.yml --auto_resume
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(
# Disable distributed.
# 2024-03-03 14:55:49,061 INFO:
#                 ____                _       _____  ____
#                / __ ) ____ _ _____ (_)_____/ ___/ / __ \
#               / __  |/ __ `// ___// // ___/\__ \ / /_/ /
#              / /_/ // /_/ /(__  )/ // /__ ___/ // _, _/
#             /_____/ \__,_//____//_/ \___//____//_/ |_|
#      ______                   __   __                 __      __
#     / ____/____   ____   ____/ /  / /   __  __ _____ / /__   / /
#    / / __ / __ \ / __ \ / __  /  / /   / / / // ___// //_/  / /
#   / /_/ // /_/ // /_/ // /_/ /  / /___/ /_/ // /__ / /<    /_/
# ...

# %%
# !python realesrgan/test.py -opt options/C0303_realesrnet_motion02_undersample_pixel.yml --auto_resume
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(
# Disable distributed.
# 2024-03-03 14:56:39,919 INFO:
#                 ____                _       _____  ____
#                / __ ) ____ _ _____ (_)_____/ ___/ / __ \
#               / __  |/ __ `// ___// // ___/\__ \ / /_/ /
#              / /_/ // /_/ /(__  )/ // /__ ___/ // _, _/
#             /_____/ \__,_//____//_/ \___//____//_/ |_|
#      ______                   __   __                 __      __
#     / ____/____   ____   ____/ /  / /   __  __ _____ / /__   / /
#    / / __ / __ \ / __ \ / __  /  / /   / / / // ___// //_/  / /
#   / /_/ // /_/ // /_/ // /_/ /  / /___/ /_/ // /__ / /<    /_/
# ...

# %%
# !zip -r /kaggle/working/test_realesrnet_motion01_pixelvsfft.zip /kaggle/working/Real-Motion-01/results
# Out:
#   adding: kaggle/working/Real-Motion-01/results/ (stored 0%)
#   adding: kaggle/working/Real-Motion-01/results/C0303_realesrnet_motion02_undersample_pixel_fft/ (stored 0%)
#   adding: kaggle/working/Real-Motion-01/results/C0303_realesrnet_motion02_undersample_pixel_fft/test_C0303_realesrnet_motion02_undersample_pixel_fft_20240303_145549.log (deflated 95%)
#   adding: kaggle/working/Real-Motion-01/results/C0303_realesrnet_motion02_undersample_pixel_fft/visualization/ (stored 0%)
#   adding: kaggle/working/Real-Motion-01/results/C0303_realesrnet_motion02_undersample_pixel_fft/visualization/run02_acc8_motion/ (stored 0%)
#   adding: kaggle/working/Real-Motion-01/results/C0303_realesrnet_motion02_undersample_pixel_fft/visualization/run02_acc8_motion/5_C0303_realesrnet_motion02_undersample_pixel_fft.png (deflated 10%)
# ...

# %%
#!zip -r /kaggle/working/test_realesrnet_motion01_pixelvsfft.zip /kaggle/working/Real-Motion-01/experiments /kaggle/working/Real-Motion-01/tb_logger
# Out:
# 	zip warning: name not matched: /kaggle/working/Real-Motion-01/tb_logger
#   adding: kaggle/working/Real-Motion-01/experiments/ (stored 0%)
#   adding: kaggle/working/Real-Motion-01/experiments/pretrained_models/ (stored 0%)
#   adding: kaggle/working/Real-Motion-01/experiments/pretrained_models/README.md (stored 0%)

# %%
# !git pull origin master
# Out:
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 7 (delta 6), reused 7 (delta 6), pack-reused 0
# Unpacking objects: 100% (7/7), 677 bytes | 338.00 KiB/s, done.
# From https://github.com/Yanlin2001/Real-Motion-01
#  * branch              master     -> FETCH_HEAD
#    279f0fd2..5015a1dd  master     -> origin/master
# Updating 279f0fd2..5015a1dd
# Fast-forward
#  ...C0228_realesrnet_motion02_undersample_30000.yml |   2 +-
#  options/X0229_realesrnet_motion02_un_mo_noise.yml  | 168 +++++++++++++++++++++
#  options/X0229_realesrnet_motion02_un_motion.yml    |   6 +-
#  options/X0229_realesrnet_motion02_undersample.yml  | 168 +++++++++++++++++++++
#  4 files changed, 340 insertions(+), 4 deletions(-)
#  create mode 100644 options/X0229_realesrnet_motion02_un_mo_noise.yml
#  create mode 100644 options/X0229_realesrnet_motion02_undersample.yml
